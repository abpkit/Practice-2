# %%
import numpy as np
import pandas as pd

# %%
female = pd.read_csv('C:/Users/Abhi/Desktop/CSV files/Women_birth.csv')
female.head()
# Out:
#          Date  Births
# 0  01-01-1959      35
# 1  02-01-1959      32
# 2  03-01-1959      30
# 3  04-01-1959      31
# 4  05-01-1959      44

# %%
# Change datatype of Date column to Datetime
female['Date'] = pd.to_datetime(female['Date'])

# %%
# Get all records for the month of Janaury(1959-01-01 - 1959-01-31). 
# Using boolean is not good method when we are dealing with large datasets.
female[(pd.to_datetime(female['Date']) > pd.Timestamp(date(1959,1,1))) &
 (pd.to_datetime(female['Date']) < pd.Timestamp(date(1959,1,31)))]

# The error is shown becaause we not imported date, so import date 1st.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-90fe9d21b9b0> in <module>
#       1 # Get all records for the month of Janaury(1959-01-01 - 1959-01-31).
#       2 # Using boolean is not good method when we are dealing with large datasets.
# ----> 3 female[(pd.to_datetime(female['Date']) > pd.Timestamp(date(1959,1,1))) &
#       4  (pd.to_datetime(female['Date']) < pd.Timestamp(date(1959,1,31)))]
#       5
#
# NameError: name 'date' is not defined

# %%
from datetime import date

# %%
# Get all records for the month of Janaury(1959-01-01 - 1959-01-31). 
# Using boolean is not good method when we are dealing with large datasets.
female[(pd.to_datetime(female['Date']) > pd.Timestamp(date(1959,1,1))) &
 (pd.to_datetime(female['Date']) < pd.Timestamp(date(1959,1,31)))]
# Out:
#           Date  Births
# 12  1959-01-13      55
# 13  1959-01-14      47
# 14  1959-01-15      45
# 15  1959-01-16      37
# 16  1959-01-17      50
# 17  1959-01-18      43
# 18  1959-01-19      41
# 19  1959-01-20      52
# 20  1959-01-21      34
# 21  1959-01-22      53
# 22  1959-01-23      39
# 23  1959-01-24      32
# 24  1959-01-25      37
# 25  1959-01-26      43
# 26  1959-01-27      39
# 27  1959-01-28      35
# 28  1959-01-29      44
# 29  1959-01-30      38
# 31  1959-01-02      23
# 59  1959-01-03      35
# 90  1959-01-04      39
# 120 1959-01-05      32
# 151 1959-01-06      45
# 181 1959-01-07      43
# 212 1959-01-08      50
# 243 1959-01-09      38
# 273 1959-01-10      49
# 304 1959-01-11      48
# 334 1959-01-12      45

# %%
# Convert date column into Datetime index for faster selection.
female = female.set_index(['Date'])
female
female.index # DatetimeIndex
# Out:
# DatetimeIndex(['1959-01-01', '1959-02-01', '1959-03-01', '1959-04-01',
#                '1959-05-01', '1959-06-01', '1959-07-01', '1959-08-01',
#                '1959-09-01', '1959-10-01',
#                ...
#                '1959-12-22', '1959-12-23', '1959-12-24', '1959-12-25',
#                '1959-12-26', '1959-12-27', '1959-12-28', '1959-12-29',
#                '1959-12-30', '1959-12-31'],
#               dtype='datetime64[ns]', name='Date', length=365, freq=None)

# %%
female
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-02-01      32
# 1959-03-01      30
# 1959-04-01      31
# 1959-05-01      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
# Now lets select the data
female.loc['1959'] # Get all data for year 1959
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-02-01      32
# 1959-03-01      30
# 1959-04-01      31
# 1959-05-01      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
#Get all rows for the month of Janaury(1959-01-01 - 1959-01-31).
female.loc['1959-01-01':'1959-01-31'][['Births']]
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-13      55
# 1959-01-14      47
# 1959-01-15      45
# 1959-01-16      37
# 1959-01-17      50
# 1959-01-18      43
# 1959-01-19      41
# 1959-01-20      52
# 1959-01-21      34
# 1959-01-22      53
# 1959-01-23      39
# 1959-01-24      32
# 1959-01-25      37
# 1959-01-26      43
# 1959-01-27      39
# 1959-01-28      35
# 1959-01-29      44
# 1959-01-30      38
# 1959-01-31      24
# 1959-01-02      23
# 1959-01-03      35
# 1959-01-04      39
# 1959-01-05      32
# 1959-01-06      45
# 1959-01-07      43
# 1959-01-08      50
# 1959-01-09      38
# 1959-01-10      49
# 1959-01-11      48
# 1959-01-12      45

# %%
# Total births in the month of January 
female.loc['1959-01-01':'1959-01-31'][['Births']].sum()
# Out:
# Births    1270
# dtype: int64

# %%
# plot line chart for January data using Pandas visualization
female.loc['1959-01-01':'1959-01-31'][['Births']].plot(figsize=(13,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import matplotlib.pyplot as plt
# plot line chart for January data using Matplotlib library
plt.figure(figsize=(13,5))
plt.plot(female.loc['1959-01-01':'1959-01-31'][['Births']])

# %%
df = pd.DataFrame({'Date':pd.date_range('1/19/1920', periods = 1200, freq ='M') ,
                   'SampleData':np.random.randint(0,200,size=None, dtype=int)})
df=df.set_index(['Date']) # Set Date column as index
df
#df.loc['2010':'2012'].plot(figsize=(16,5)) # Plot line chart for data between 2010-2012
# Out:
#             SampleData
# Date
# 1920-01-31          46
# 1920-02-29          46
# 1920-03-31          46
# 1920-04-30          46
# 1920-05-31          46
# ...                ...
# 2019-08-31          46
# 2019-09-30          46
# 2019-10-31          46
# 2019-11-30          46
# 2019-12-31          46
#
# [1200 rows x 1 columns]

# %%
df.loc['2010':'2012'].plot(figsize=(16,5)) # Plot line chart for data between 2010-2012
# Out:
# <AxesSubplot:xlabel='Date'>
